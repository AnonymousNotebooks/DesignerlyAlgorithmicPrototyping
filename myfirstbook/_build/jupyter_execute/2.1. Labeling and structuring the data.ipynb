# %% [markdown]
# # 2. Labeling, structuring and visualizing the data
# In this step, we wanted to gain an understanding of how the collected data could inform ML-generated predictions. To do so, we started by organizing and structuring the datasets so that they could be used to create meaningful visualizations, and to enable its interpretation by an algorithm. Where necessary, we added labels that add a layer of meaningful information to the data for the algorithm to use. For the grocery automation case study, we poured the data into a full dataset of all items bought by each individual household. Examples of labels that were added to the data are: an identification of what types of items each item name signified (e.g., “Old Goudse 45+” is cheese); an identification of what type of store the items were bought at (e.g., “Albert Heijn” is a supermarket), and assigning a category to which each item belongs (e.g., milk is a dairy product).
#
# In this notebook (2.1) we:
# - Import the library/dataframe and recode/add all required variables (2.1 Labeling and structuring)
#
# In the next notebook (2.2) we:
# - Generate visualizations and correlations to analyze the data (2.2 Visualizing)

# %% [markdown]
# ## 2.1. Labeling and structuring

# %% [markdown]
# ### Import libraries

# %%
#Pandas is a software library written for the Python programming language for data manipulation and analysis.
import pandas as pd
#NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays
import numpy as np
# Matplotlib is a plotting library for python and pyplot gives us a MatLab like plotting framework. We will use this in our plotter function to plot data.
import matplotlib.pyplot as plt
#Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics
import seaborn as sns

# %% [markdown]
# ### Load and view data

# %%
df = pd.read_csv (r"/workspaces/DesignerlyAlgorithmicPrototyping/database/DATA-HH (dummy).csv")

del df["HH"]
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/plenty-in-the-pantry--3J3HE2a-py3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HH'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 3
#       1 df = pd.read_csv (r"/workspaces/DesignerlyAlgorithmicPrototyping/database/DATA-HH (dummy).csv")
# ----> 3 del df["HH"]
#       4 df.head()
#
# File ~/.cache/pypoetry/virtualenvs/plenty-in-the-pantry--3J3HE2a-py3.10/lib/python3.10/site-packages/pandas/core/generic.py:4500, in NDFrame.__delitem__(self, key)
#    4495             deleted = True
#    4496 if not deleted:
#    4497     # If the above loop ran and didn't delete anything because
#    4498     # there was no match, this call should raise the appropriate
#    4499     # exception:
# -> 4500     loc = self.axes[-1].get_loc(key)
#    4501     self._mgr = self._mgr.idelete(loc)
#    4503 # delete from the caches
#
# File ~/.cache/pypoetry/virtualenvs/plenty-in-the-pantry--3J3HE2a-py3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'HH'

# %% [markdown]
# ## Recode variables
#
# Create (number) IDs for certain variables (item type, order...)
# Create new derived variables (e.g. reordering an item, total order price...)
# Make sure all variables are formatted as the correct type (e.g., int, bool...)

# %%
# new row for reordered items 
df['reorder'] = df.item_type.duplicated()

# convert reorder row to boolean value
df['reorder'] = df['reorder'].astype(bool)

#create an ID for each item 
df.rename(columns={'item_id':'item_name'}, inplace=True)
df['item_id'] = pd.factorize(df['item_name'])[0]

#create an ID for each type 
df['type_id'] = pd.factorize(df['item_type'])[0]

#first make a new column for the amount of items per order
df['order_amount'] = df.groupby('order_ID')['amount'].transform('sum')

# make a new column for the price per order
df['order_price'] = df.groupby('order_ID')['price_total'].transform('sum')

# %%
df['week'] = df['week'].astype(int)

df['order_ID'] = df['order_ID'].astype(int)

df['amount'] = df['amount'].astype(int)

df['promo'] = df['promo'].astype(bool)

df['item_id'] = df['item_id'].astype(int)

df['type_id'] = df['type_id'].astype(int)

# %%
df_des = df.describe(include='all')

df_styled = df_des.style.background_gradient() #adding a gradient based on values in cell
# dfi.export(df_styled,"describeHH2.png")
df_styled
# Out:
# <style type="text/css">
# #T_33457_row0_col0, #T_33457_row0_col1, #T_33457_row0_col3, #T_33457_row0_col4, #T_33457_row0_col5, #T_33457_row0_col16, #T_33457_row0_col17, #T_33457_row0_col18, #T_33457_row0_col19 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_33457_row1_col0, #T_33457_row1_col1, #T_33457_row1_col3, #T_33457_row1_col4, #T_33457_row1_col5, #T_33457_row1_col16, #T_33457_row1_col17, #T_33457_row1_col18, #T_33457_row1_col19, #T_33457_row2_col0, #T_33457_row2_col1, #T_33457_row2_col3, #T_33457_row2_col4, #T_33457_row2_col5, #T_33457_row2_col16, #T_33457_row2_col17, #T_33457_row2_col18, #T_33457_row2_col19, #T_33457_row3_col0, #T_33457_row3_col1, #T_33457_row3_col3, #T_33457_row3_col4, #T_33457_row3_col5, #T_33457_row3_col16, #T_33457_row3_col17, #T_33457_row3_col18, #T_33457_row3_col19 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_33457_row4_col0, #T_33457_row8_col0, #T_33457_row9_col0, #T_33457_row9_col4, #T_33457_row9_col5 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_33457_row4_col1, #T_33457_row8_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_33457_row4_col3, #T_33457_row5_col0, #T_33457_row5_col3, #T_33457_row6_col0, #T_33457_row6_col1, #T_33457_row6_col3, #T_33457_row6_col4, #T_33457_row6_col5, #T_33457_row6_col16, #T_33457_row6_col17, #T_33457_row6_col18, #T_33457_row6_col19, #T_33457_row7_col0, #T_33457_row7_col3, #T_33457_row7_col4, #T_33457_row8_col3, #T_33457_row9_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_33457_row4_col4, #T_33457_row4_col5, #T_33457_row5_col4, #T_33457_row5_col5, #T_33457_row7_col5, #T_33457_row8_col4, #T_33457_row8_col5 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_33457_row4_col16 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_33457_row4_col17 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_33457_row4_col18 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_33457_row4_col19 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_33457_row5_col1, #T_33457_row7_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_33457_row5_col16 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_33457_row5_col17, #T_33457_row5_col19, #T_33457_row8_col17 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_33457_row5_col18, #T_33457_row10_col4, #T_33457_row10_col5 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_33457_row7_col16 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_33457_row7_col17, #T_33457_row10_col3 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_33457_row7_col18 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_33457_row7_col19 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_33457_row8_col16 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_33457_row8_col18 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_33457_row8_col19 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_33457_row9_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_33457_row9_col16 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_33457_row9_col17 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_33457_row9_col18, #T_33457_row10_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_33457_row9_col19 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_33457_row10_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_33457_row10_col16 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_33457_row10_col17 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_33457_row10_col18 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_33457_row10_col19 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# </style>
# <table id="T_33457">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33457_level0_col0" class="col_heading level0 col0" >week</th>
#       <th id="T_33457_level0_col1" class="col_heading level0 col1" >order_ID</th>
#       <th id="T_33457_level0_col2" class="col_heading level0 col2" >item_name</th>
#       <th id="T_33457_level0_col3" class="col_heading level0 col3" >amount</th>
#       <th id="T_33457_level0_col4" class="col_heading level0 col4" >price_unit</th>
#       <th id="T_33457_level0_col5" class="col_heading level0 col5" >price_total</th>
#       <th id="T_33457_level0_col6" class="col_heading level0 col6" >date</th>
#       <th id="T_33457_level0_col7" class="col_heading level0 col7" >day</th>
#       <th id="T_33457_level0_col8" class="col_heading level0 col8" >timestamp</th>
#       <th id="T_33457_level0_col9" class="col_heading level0 col9" >time</th>
#       <th id="T_33457_level0_col10" class="col_heading level0 col10" >store_type</th>
#       <th id="T_33457_level0_col11" class="col_heading level0 col11" >store_name</th>
#       <th id="T_33457_level0_col12" class="col_heading level0 col12" >promo</th>
#       <th id="T_33457_level0_col13" class="col_heading level0 col13" >item_type</th>
#       <th id="T_33457_level0_col14" class="col_heading level0 col14" >category</th>
#       <th id="T_33457_level0_col15" class="col_heading level0 col15" >reorder</th>
#       <th id="T_33457_level0_col16" class="col_heading level0 col16" >item_id</th>
#       <th id="T_33457_level0_col17" class="col_heading level0 col17" >type_id</th>
#       <th id="T_33457_level0_col18" class="col_heading level0 col18" >order_amount</th>
#       <th id="T_33457_level0_col19" class="col_heading level0 col19" >order_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33457_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_33457_row0_col0" class="data row0 col0" >372.000000</td>
#       <td id="T_33457_row0_col1" class="data row0 col1" >372.000000</td>
#       <td id="T_33457_row0_col2" class="data row0 col2" >372</td>
#       <td id="T_33457_row0_col3" class="data row0 col3" >372.000000</td>
#       <td id="T_33457_row0_col4" class="data row0 col4" >372.000000</td>
#       <td id="T_33457_row0_col5" class="data row0 col5" >372.000000</td>
#       <td id="T_33457_row0_col6" class="data row0 col6" >372</td>
#       <td id="T_33457_row0_col7" class="data row0 col7" >372</td>
#       <td id="T_33457_row0_col8" class="data row0 col8" >372</td>
#       <td id="T_33457_row0_col9" class="data row0 col9" >372</td>
#       <td id="T_33457_row0_col10" class="data row0 col10" >372</td>
#       <td id="T_33457_row0_col11" class="data row0 col11" >372</td>
#       <td id="T_33457_row0_col12" class="data row0 col12" >372</td>
#       <td id="T_33457_row0_col13" class="data row0 col13" >372</td>
#       <td id="T_33457_row0_col14" class="data row0 col14" >372</td>
#       <td id="T_33457_row0_col15" class="data row0 col15" >372</td>
#       <td id="T_33457_row0_col16" class="data row0 col16" >372.000000</td>
#       <td id="T_33457_row0_col17" class="data row0 col17" >372.000000</td>
#       <td id="T_33457_row0_col18" class="data row0 col18" >372.000000</td>
#       <td id="T_33457_row0_col19" class="data row0 col19" >372.000000</td>
#     </tr>
#     <tr>
#       <th id="T_33457_level0_row1" class="row_heading level0 row1" >unique</th>
#       <td id="T_33457_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_33457_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_33457_row1_col2" class="data row1 col2" >314</td>
#       <td id="T_33457_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_33457_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_33457_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_33457_row1_col6" class="data row1 col6" >26</td>
#       <td id="T_33457_row1_col7" class="data row1 col7" >7</td>
#       <td id="T_33457_row1_col8" class="data row1 col8" >35</td>
#       <td id="T_33457_row1_col9" class="data row1 col9" >4</td>
#       <td id="T_33457_row1_col10" class="data row1 col10" >5</td>
#       <td id="T_33457_row1_col11" class="data row1 col11" >9</td>
#       <td id="T_33457_row1_col12" class="data row1 col12" >2</td>
#       <td id="T_33457_row1_col13" class="data row1 col13" >126</td>
#       <td id="T_33457_row1_col14" class="data row1 col14" >16</td>
#       <td id="T_33457_row1_col15" clas

# %%
df.dtypes
# Out:
# week              int64
# order_ID          int64
# item_name        object
# amount            int64
# price_unit      float64
# price_total     float64
# date             object
# day              object
# timestamp        object
# time             object
# store_type       object
# store_name       object
# promo              bool
# item_type        object
# category         object
# reorder            bool
# item_id           int64
# type_id           int64
# order_amount      int64
# order_price     float64
# dtype: object

# %% [markdown]
# ### New (numeric) variables for the confusion matrix
#
# Turn numeric values into category codes (to facilitate making the confusion matrix)

# %%
# Recode dow
df['day_num']=df['day'].astype('category').cat.codes

# Recode store_type
df['storetype_num']=df['store_type'].astype('category').cat.codes

# Recode store_name
df['storename_num']=df['store_name'].astype('category').cat.codes

# Recode categories
df['cat_num']=df['category'].astype('category').cat.codes

# Recode time
df['time_num']=df['time'].astype('category').cat.codes

# Recode time
df['promo_num']=df['promo'].astype('category').cat.codes

# %%
df.dtypes
# Out:
# week               int64
# order_ID           int64
# item_name         object
# amount             int64
# price_unit       float64
# price_total      float64
# date              object
# day               object
# timestamp         object
# time              object
# store_type        object
# store_name        object
# promo               bool
# item_type         object
# category          object
# reorder             bool
# item_id            int64
# type_id            int64
# order_amount       int64
# order_price      float64
# day_num             int8
# storetype_num       int8
# storename_num       int8
# cat_num             int8
# time_num            int8
# promo_num           int8
# dtype: object

# %% [markdown]
# ## Save the final dataframe as a new csv file

# %%
df.head()
# Out:
#    week  order_ID                               item_name  amount  price_unit  \
# 0     1         1                 RABEKO choco light 250g       2        2.82
# 1     1         1  JOYVALLE pudding griesmeel natuur 135g       4        0.99
# 2     1         1    BONI tomatensoep met balletjes 950ml       1        1.99
# 3     1         1      LIEBIG DELISOUP 9 groenten brik 1L       1        2.59
# 4     1         1  LIEBIG DELISOUP tom. Balletjes brik 1L       1        2.59
#
#    price_total        date      day timestamp  time  ... item_id type_id  \
# 0         5.64  2021-11-23  Tuesday  12:32:00  noon  ...       0       0
# 1         3.96  2021-11-23  Tuesday  12:32:00  noon  ...       1       1
# 2         1.99  2021-11-23  Tuesday  12:32:00  noon  ...       2       2
# 3         2.59  2021-11-23  Tuesday  12:32:00  noon  ...       3       2
# 4         2.59  2021-11-23  Tuesday  12:32:00  noon  ...       4       2
#
#    order_amount order_price day_num  storetype_num  storename_num  cat_num  \
# 0             9       16.77       5              4              6        2
# 1             9       16.77       5              4              6        7
# 2             9       16.77       5              4              6        3
# 3             9       16.77       5              4              6        3
# 4             9       16.77       5              4              6        3
#
#    time_num  promo_num
# 0         3          0
# 1         3          0
# 2         3          0
# 3         3          0
# 4         3          0
#
# [5 rows x 26 columns]

# %%
df.to_csv(r"/workspaces/DesignerlyAlgorithmicPrototyping/database/DATA-HH (dummy).csv", index=False)

# %%
# Get simplified dataframe (no cat num etc.)
df.drop(["storename_num", 'cat_num', 'time_num', 'promo_num', 'timestamp'], axis=1, inplace=True)
df.drop(['day_num', 'storetype_num', 'reorder'], axis=1, inplace=True)
df.head()
# Out:
#    week  order_ID                               item_name  amount  price_unit  \
# 0     1         1                 RABEKO choco light 250g       2        2.82
# 1     1         1  JOYVALLE pudding griesmeel natuur 135g       4        0.99
# 2     1         1    BONI tomatensoep met balletjes 950ml       1        1.99
# 3     1         1      LIEBIG DELISOUP 9 groenten brik 1L       1        2.59
# 4     1         1  LIEBIG DELISOUP tom. Balletjes brik 1L       1        2.59
#
#    price_total        date      day  time   store_type store_name  promo  \
# 0         5.64  2021-11-23  Tuesday  noon  supermarket       Okay  False
# 1         3.96  2021-11-23  Tuesday  noon  supermarket       Okay  False
# 2         1.99  2021-11-23  Tuesday  noon  supermarket       Okay  False
# 3         2.59  2021-11-23  Tuesday  noon  supermarket       Okay  False
# 4         2.59  2021-11-23  Tuesday  noon  supermarket       Okay  False
#
#           item_type             category  item_id  type_id  order_amount  \
# 0  chocolate spread  breakfast & spreads        0        0             9
# 1           pudding  dairy & plant based        1        1             9
# 2              soup         canned foods        2        2             9
# 3              soup         canned foods        3        2             9
# 4              soup         canned foods        4        2             9
#
#    order_price
# 0        16.77
# 1        16.77
# 2        16.77
# 3        16.77
# 4        16.77
